# %% [markdown]
# # Create model

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Load dataset
df = pd.read_csv("../data/wearable_tech_sleep_quality.csv")  # Replace with actual file path

# %%
# Filter out rows where Sleep Stage is 'Awake'
df = df[df["Sleep Stage"] != "Awake"]

# %%
# Drop the 'Body Temperature' attribute
df = df.drop(columns=["Body Temperature"])

# %%
# Define features and target
X = df.drop(columns=["Sleep Stage"])
y = df["Sleep Stage"]

# %%
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2001)

# %%
X_train
# Out:
#       heartrate  temperature  humidity
# 2290         68           23        68
# 2594         80           15        44
# 4734         56           16        63
# 2364         95           20        70
# 465          80           20        76
# ...         ...          ...       ...
# 1356         74           16        30
# 3689         62           26        48
# 2776         56           25        45
# 3278         62           29        68
# 2081         52           22        56
#
# [2985 rows x 3 columns]

# %%
# Train Random Forest classifier
clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    min_samples_split=4,
    min_samples_leaf=2,
    criterion="entropy",
    n_jobs=-1,
    random_state=1992
)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, min_samples_leaf=2,
#                        min_samples_split=4, n_jobs=-1, random_state=1992)

# %%
# Make predictions
y_pred = clf.predict(X_test)

# %%
X_test
# Out:
#       heartrate  temperature  humidity
# 4459         89           24        68
# 3982         62           17        77
# 2211         53           20        58
# 2017        105           20        77
# 4327         95           29        65
# ...         ...          ...       ...
# 3495         62           15        53
# 1263        106           24        60
# 3958         81           21        43
# 2763         68           28        52
# 2078         60           28        79
#
# [747 rows x 3 columns]

# %%
y_pred
# Out:
# array(['Light', 'Deep', 'REM', 'Light', 'REM', 'Deep', 'REM', 'REM',
#        'REM', 'REM', 'REM', 'Light', 'REM', 'Deep', 'REM', 'Light',
#        'Light', 'Deep', 'Deep', 'REM', 'Light', 'REM', 'REM', 'REM',
#        'REM', 'REM', 'Deep', 'Deep', 'Light', 'REM', 'REM', 'Deep', 'REM',
#        'Light', 'Light', 'REM', 'REM', 'Light', 'Light', 'REM', 'REM',
#        'Deep', 'Light', 'REM', 'Light', 'REM', 'REM', 'REM', 'Light',
#        'Deep', 'Light', 'REM', 'Deep', 'REM', 'REM', 'Deep', 'REM', 'REM',
#        'Light', 'Deep', 'Light', 'Light', 'Light', 'Light', 'Light',
#        'Light', 'Light', 'REM', 'Light', 'Light', 'REM', 'REM', 'REM',
#        'REM', 'REM', 'Deep', 'Light', 'Light', 'Light', 'Light', 'Light',
#        'REM', 'REM', 'Deep', 'REM', 'Light', 'Deep', 'REM', 'Light',
#        'REM', 'REM', 'Deep', 'REM', 'Light', 'REM', 'Deep', 'Light',
#        'Light', 'Light', 'Light', 'Deep', 'Light', 'REM', 'Deep', 'REM',
#        'Light', 'REM', 'REM', 'REM', 'Deep', 'Deep', 'Deep', 'Light',
#        'REM', 'REM', 'Deep', 'REM', 'REM', 'REM', 'Light', 'REM', 'Deep',
#        'Light', 'Deep', 'Light', 'Light', 'Light', 'Deep', 'REM', 'Deep',
#        'REM', 'REM', 'REM', 'Deep', 'Deep', 'Deep', 'Light', 'Light',
#        'Deep', 'Deep', 'Light', 'REM', 'REM', 'Light', 'REM', 'REM',
#        'REM', 'REM', 'Deep', 'Light', 'Light', 'Light', 'REM', 'REM',
#        'Deep', 'Light', 'Deep', 'Light', 'Light', 'REM', 'REM', 'Light',
#        'Light', 'REM', 'Light', 'REM', 'Light', 'REM', 'Light', 'Deep',
#        'REM', 'Deep', 'Light', 'REM', 'Light', 'REM', 'Deep', 'Light',
#        'Light', 'REM', 'Deep', 'Light', 'REM', 'Light', 'REM', 'Deep',
#        'REM', 'REM', 'Light', 'Deep', 'REM', 'Light', 'Light', 'Light',
#        'Light', 'Light', 'REM', 'REM', 'Light', 'REM', 'REM', 'Light',
#        'Deep', 'Deep', 'Deep', 'REM', 'REM', 'Deep', 'Light', 'Light',
#        'Light', 'Light', 'REM', 'Light', 'REM', 'Deep', 'REM', 'Light',
#        'Light', 'Light', 'Light', 'REM', 'REM', 'Light', 'Light', 'Light',
#        'Deep', 'Deep', 'REM', 'Deep', 'REM', 'Light', 'REM', 'Light',
#        'Deep', 'REM', 'REM', 'REM', 'Deep', 'REM', 'REM', 'Light', 'REM',
#        'REM', 'Light', 'Light', 'REM', 'Deep', 'Light', 'REM', 'REM',
#        'REM', 'Deep', 'Light', 'Light', 'Light', 'REM', 'REM', 'REM',
#        'Deep', 'Deep', 'Light', 'Deep', 'Deep', 'Deep', 'Light', 'REM',
#        'Light', 'REM', 'Light', 'Light', 'REM', 'Deep', 'REM', 'REM',
#        'REM', 'Light', 'Deep', 'Deep', 'Deep', 'Deep', 'Deep', 'Light',
#        'REM', 'REM', 'Deep', 'REM', 'Deep', 'REM', 'Light', 'Light',
#        'REM', 'Deep', 'Light', 'Deep', 'Deep', 'Light', 'Deep', 'REM',
#        'Deep', 'Deep', 'REM', 'Deep', 'REM', 'Deep', 'Light', 'REM',
#        'Light', 'REM', 'REM', 'REM', 'Light', 'Deep', 'Deep', 'Light',
#        'REM', 'REM', 'REM', 'Deep', 'Light', 'Light', 'Light', 'Light',
#        'Light', 'Light', 'REM', 'Light', 'Light', 'REM', 'REM', 'Deep',
#        'Light', 'REM', 'Light', 'REM', 'Light', 'Deep', 'Deep', 'Light',
#        'Deep', 'REM', 'REM', 'REM', 'Deep', 'REM', 'Light', 'Light',
#        'Light', 'Deep', 'Light', 'Deep', 'Light', 'Light', 'REM', 'REM',
#        'Light', 'Light', 'Light', 'REM', 'Light', 'REM', 'Light', 'Deep',
#        'Light', 'REM', 'Light', 'REM', 'REM', 'Deep', 'REM', 'Light',
#        'Light', 'REM', 'Light', 'REM', 'REM', 'REM', 'REM', 'REM', 'Deep',
#        'Light', 'REM', 'Light', 'REM', 'Light', 'REM', 'REM', 'Deep',
#        'REM', 'Light', 'REM', 'Light', 'Deep', 'REM', 'REM', 'Light',
#        'Light', 'REM', 'Deep', 'Light', 'REM', 'Light', 'REM', 'REM',
#        'Light', 'Deep', 'REM', 'REM', 'REM', 'Light', 'REM', 'Light',
#        'Deep', 'Deep', 'Light', 'Deep', 'Light', 'Light', 'Light',
#        'Light', 'Light', 'REM', 'REM', 'Light', 'Deep', 'REM', 'REM',
#        'REM', 'REM', 'Light', 'Deep', 'REM', 'REM', 'Light', 'Light',
#        'Light', 'Deep', 'Light', 'REM', 'Light', 'REM', 'Deep', 'REM',
#        'Deep', 'REM', 'REM', 'REM', 'Deep', 'REM', 'REM', 'REM', 'Light',
#        'Light', 'REM', 'Light', 'REM', 'Deep', 'Deep', 'Light', 'Deep',
#        'Light', 'REM', 'REM', 'REM', 'REM', 'REM', 'Deep', 'Light',
#        'Light', 'REM', 'REM', 'Light', 'REM', 'REM', 'Light', 'REM',
#        'Deep', 'Light', 'Light', 'REM', 'Deep', 'Deep', 'REM', 'Light',
#        'Light', 'REM', 'Light', 'Deep', 'REM', 'Light', 'Light', 'Light',
#        'Deep', 'REM', 'REM', 'Light', 'Deep', 'Deep', 'REM', 'REM', 'REM',
#        'Deep', 'Light', 'Light', 'Deep', 'Light', 'Light', 'Light', 'REM',
#        'Deep', 'Deep', 'REM', 'Light', 'REM', 'REM', 'Light', 'Deep',
#        'REM', 'Deep', 'Deep', 'REM', 'Deep', 'Light', 'Light', 'Deep',
#        'Deep', 'Deep', 'Deep', 'Deep', 'REM', 'Light', 'REM', 'Deep',
#        'Light', 'REM', 'REM', 'REM', 'Light', 'Light', 'REM', 'Deep',
#        'REM', 'Light', 'REM', 'Deep', 'REM', 'Light', 'REM', 'REM', 'REM',
#        'REM', 'REM', 'REM', 'REM', 'REM', 'Light', 'Deep', 'REM', 'REM',
#        'REM', 'REM', 'Light', 'Light', 'REM', 'Light', 'REM', 'Light',
#        'REM', 'REM', 'REM', 'Deep', 'REM', 'REM', 'REM', 'Light', 'Light',
#        'REM', 'REM', 'REM', 'Deep', 'REM', 'Deep', 'REM', 'Deep', 'REM',
#        'Light', 'Deep', 'Light', 'Light', 'Deep', 'Light', 'REM', 'REM',
#        'REM', 'REM', 'Light', 'REM', 'Light', 'REM', 'Light', 'Deep',
#        'Deep', 'Deep', 'Deep', 'Light', 'Light', 'Light', 'Deep', 'Light',
#        'Deep', 'Light', 'REM', 'Light', 'Light', 'Light', 'REM', 'Light',
#        'REM', 'REM', 'Deep', 'Deep', 'REM', 'Light', 'Deep', 'REM', 'REM',
#        'Light', 'REM', 'REM', 'Deep', 'Deep', 'Deep', 'Light', 'Light',
#        'REM', 'REM', 'Light', 'REM', 'REM', 'Light', 'Light', 'REM',
#        'Light', 'REM', 'Deep', 'REM', 'REM', 'REM', 'Deep', 'REM', 'REM',
#        'Deep', 'REM', 'REM', 'Deep', 'REM', 'Deep', 'Light', 'Deep',
#        'Light', 'REM', 'REM', 'Deep', 'Deep', 'Deep', 'Light', 'Deep',
#        'REM', 'REM', 'Light', 'REM', 'Light', 'REM', 'Light', 'Deep',
#        'Light', 'Deep', 'REM', 'REM', 'Deep', 'Deep', 'REM', 'REM',
#        'Deep', 'Deep', 'Deep', 'Light', 'REM', 'Light', 'Light', 'Light',
#        'Deep', 'REM', 'REM', 'Light', 'Deep', 'REM', 'Light', 'REM',
#        'REM', 'Light', 'REM', 'REM', 'Light', 'Light', 'REM', 'REM',
#        'Light', 'Light', 'REM', 'Light', 'REM', 'REM', 'Light', 'Light',
#        'Deep', 'Light', 'Deep', 'Light', 'REM', 'REM', 'REM', 'REM',
#        'Light', 'Deep', 'REM', 'Light', 'REM', 'Light', 'REM', 'REM',
#        'Light', 'Light', 'REM', 'REM', 'REM', 'Light', 'Light', 'REM',
#        'Light', 'REM', 'REM', 'REM', 'REM', 'Light', 'REM', 'Light'],
#       dtype=object)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3467202141900937

# %% [markdown]
# # Save model

# %%
import pickle

# save the iris classification model as a pickle file
model_pkl_file = "sleep_stage_model.pkl"  

with open(model_pkl_file, 'wb') as file:  
    pickle.dump(clf, file)
